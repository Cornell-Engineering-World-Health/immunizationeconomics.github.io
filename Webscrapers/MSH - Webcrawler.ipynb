, appui technique, coordination locale… S’assurer de l’exposition et la contribution des groupes d’épargnes pratiquant la protection financière aux\xa0 différentes interventions de ACCESS destinées à générer des demandes aux soins et à inciter aux changements de comportements (Approche championne, TAFA, SAHA, …) Elaborer des plans d’action périodique avec les partenaires et effectuer des visites de suivis réguliers des avancements des activités et des réalisations. S’assurer d’une communication effective, constructive et en temps réel avec son superviseur pour la bonne marche des interventions terrain. Fournir les éléments qualitatifs en lien avec les performances des groupes d’épargne en matière de protection financière afin d’appuyer son superviseur dans l’élaboration des rapports périodiques. Identifier et rapporter les bonnes pratiques, les cas de succès stories, les anomalies ainsi que les problèmes rencontrés.\xa0\xa0 Etablir des relations de travail saines avec les autorités locales, administratives et coutumières et les autres acteurs d’urgences et de développement dans les communes d’intervention Participer à toutes les réunions de coordination organisées par le superviseur technique. Fournir un rapport mensuel narratif et qualitatif de ses interventions et activités durant le mois passe et des propositions de plan d’action pour le mois à venir, en se basant sur l’analyse de performance de ses PSP Qualifications Niveau Licence au minimum ou équivalent avec 02 ans d’expérience en ONG\xa0 Excellente capacité en mobilisation communautaires et formations des adultes Bonnes connaissances de l’approche SILC\xa0/ VSLA Capacité de négociation et communication verbale, discussion et échange avec les autorités locales (traditionnelles, administratives et religieuse) Expérience professionnelle dans la sensibilisation, l’animation, l’éducation des adultes, la gestion de conflits, l’organisation événementielle\xa0 Bonnes connaissances des communes d’affectation (dialecte, us et coutumes, contexte social et économique…) et capacité à communiquer et collaborer avec leaders communautaires Excellentes aptitudes de communication verbale, écrite, interpersonnelles et organisationnelle, particulièrement au niveau des communautés Connaissance du français écrit et parlé et du dialecte locale des zones d’affectation Maitrise de l’outil informatique (pack Office, gest ...

# %%
from crawler import get_job_postings
import os, json
import pandas as pd
import requests

#data = get_job_postings('https://msh.wd1.myworkdayjobs.com/en-US/External',4,False)
#print(data)

immunization_keywords = ['Immunization', 'immunisation', 'vaccine', 'vaccines','vaccine-preventable diseases', 'vpd outbreak',
                        'immunization campaign', 'SIA','supplemental immunization act ivities', 'cold chain', 'GAVI','shigella', 'cholera',
                        'bcg', 'dtp', 'dpt', 'measles', 'influenza', 'conjugate vaccine']
            
economics_keywords = ['Economics','expenditure tracking', 'financing', 
                    'value for vaccination' , 'costing', 'economic analysis','costs' , 'equity', 'cost effectiveness', 'cost-effectiveness', 
                    'cost benefit analysis', 'benefit-cost analysis','cost utility analysis','budget impact analysis' , 'budget' , 'budgeting' , 
                    'GAVI','funding gap','fiscal']


new_json_files = []
#print(data)
for json_text in data:
    #print(json_text)
    desc = json_text['description']
    imm_result = any(ele in desc for ele in immunization_keywords)
    ec_result = any(ele in desc for ele in economics_keywords)
    #print(result)
    if (imm_result or ec_result):
        if json_text not in new_json_files:
            json_text['immunization'] = imm_result
            json_text['economics'] = ec_result
            new_json_files.append(json_text)  
                
#print(new_json_files)

job_position = []
description_and_requirements = []
location = []
ImmEcs = []
organization = []

for index in new_json_files:
    #print(index)   
    jp = index['labels'][0]
    job_position.append(jp)
    #print(job_position)
    description = index['description']
    description_and_requirements.append(description)
    #print(description_and_requirements)
    loc = index['labels'][2]
    location.append(loc)
    #print(location)
    if (imm_result and ec_result): ImmEcs.append('Both')
    elif imm_result: ImmEcs.append('Immunization')
    else: ImmEcs.append('Economics')
    organization.append('MSH')

DataFrame = pd.DataFrame() 
DataFrame['Job']= job_position 
DataFrame['Location'] = location
DataFrame['Type'] = ImmEcs
DataFrame['Description'] = description_and_requirements 
DataFrame['Organization'] = organization

Data = DataFrame.drop_duplicates() 
Data.to_csv("MSH_Data.csv")
print('Done')
# Out:
# Done
