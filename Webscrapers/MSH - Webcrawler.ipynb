# %%
data = get_job_postings('https://msh.wd1.myworkdayjobs.com/en-US/External',4,False)
#print(data)
# Out:
# printingpostings
# []
# printingpostings
# [{'labels': ['Spécialiste du renforcement des capacités cliniques du district - Vatomandry (Région Atsinanana)', 'R733', 'Madagascar-Atsinanana', 'Posted Today'], 'description': "MISSION PRINCIPALE Le Spécialiste du renforcement des compétences cliniques au niveau de district travaille ensemble avec l'EMAD pour identifier, planifier et mettre en œuvre le renforcement des compétences basées sur les besoins identifiés en visant à améliorer la qualité des services de SMNE dans les hôpitaux de district et les CSB. Il/elle veille à ce que le projet reste conforme aux objectifs des activités de renforcement des capacités cliniques et aux objectifs de la SMNE dans le district. RESPONSIBILITÉS SPÉCIFIQUES En collaboration avec le Coordonnateur Régional du Renforcement des Compétences Cliniques, il/elle aidera l'EMAD à développer la formation polyvalente optimale, par un appui formatif et de mentorat sur site et hors site pour chaque lacune de performance clinique identifiée. Assister l'EMAD à dispenser une formation clinique initiale adaptée au curriculum actualisé pour le personnel des hôpitaux et des CSB du district. Aider l'EMAD à optimiser les prestations des mentors cliniques afin d'améliorer la prestation de services, en ciblant les CSB et les hôpitaux de district par une assistance technique adaptée. Veiller à ce que l’orientation des interventions cliniques, activités et programme soient mise en œuvre avec une haute qualité technique et à ce que les produits associés soient livrés à temps aux bénéficiaires. Veiller à ce que les mentors cliniques aident les établissements de santé à assurer la qualité des services cliniques et à mettre en place un système continu d’assurance qualité. Contribuer à l’élaboration du plan de Santé du District et au suivi des progrès réalisés dans les activités / performances de renforcement des compétences cliniques par rapport au plan de travail, et en respectant les exigences du rapportage. Fournir un suivi sur le terrain et documenter les progrès accomplis dans la prestation de services de haute qualité en SMNE, y compris le PEV et le paludisme au niveau de l'établissement de santé dans le district. Assister et aider l'EMAD à identifier les opportunités et à coordonner les activités de renforcement des compétences cliniques avec d'autres bailleurs de fonds internationaux\xa0sur des questions de gestion clinique ou d'autres domaines pertinents dans le district. Assurer la supervision technique des activités de renforcement des compétentes cliniques dans le district. Assurer la soumission en temps des rapports d'avancement des activités au coordinateur du renforcement des compétences cliniques et au coordinateur de district S'acquitter de toutes autres tâches assignées QUALIFICATIONS REQUISES Diplôme universitaire supérieur en prestation de services cliniques (médecin, infirmière sage-femme ou équivalent) Deux à trois ans d'expérience en assistance technique aux prestataires de services de SR / PF, SMNE, paludisme et PEV, y compris la formation / coaching / mentorat clinique, et dans le suivi des livrables et des résultats des services cliniques. Connaissance significative du système de santé de Madagascar. Expérience de travail sur des programmes financés par l'USAID est un avantage. Expérience dans l'élaboration et la prestation de formations et d'ateliers. Expérience de la formation, de l'encadrement et du mentorat; expérience de la mise en place de programmes de formation et d'ateliers est souhaité. Aptitude avérée à interagir de manière professionnelle et efficace avec les cadres supérieurs, les décideurs, les responsables gouvernementaux et la société civile. Compétences pratiques et analytiques nécessaires pour interpréter des données ou des informations en actions concrètes. Créativité, adaptabilité et capacité à appliquer une pensée innovatrice et à résoudre des problèmes. Compétences fortes en informatique et en écriture. Volonté et capacité à s'adapter aux besoins du programme en foncti ...
# printingpostings
# [{'labels': ['Spécialiste du renforcement des capacités cliniques du district - Vatomandry (Région Atsinanana)', 'R733', 'Madagascar-Atsinanana', 'Posted Today'], 'description': "MISSION PRINCIPALE Le Spécialiste du renforcement des compétences cliniques au niveau de district travaille ensemble avec l'EMAD pour identifier, planifier et mettre en œuvre le renforcement des compétences basées sur les besoins identifiés en visant à améliorer la qualité des services de SMNE dans les hôpitaux de district et les CSB. Il/elle veille à ce que le projet reste conforme aux objectifs des activités de renforcement des capacités cliniques et aux objectifs de la SMNE dans le district. RESPONSIBILITÉS SPÉCIFIQUES En collaboration avec le Coordonnateur Régional du Renforcement des Compétences Cliniques, il/elle aidera l'EMAD à développer la formation polyvalente optimale, par un appui formatif et de mentorat sur site et hors site pour chaque lacune de performance clinique identifiée. Assister l'EMAD à dispenser une formation clinique initiale adaptée au curriculum actualisé pour le personnel des hôpitaux et des CSB du district. Aider l'EMAD à optimiser les prestations des mentors cliniques afin d'améliorer la prestation de services, en ciblant les CSB et les hôpitaux de district par une assistance technique adaptée. Veiller à ce que l’orientation des interventions cliniques, activités et programme soient mise en œuvre avec une haute qualité technique et à ce que les produits associés soient livrés à temps aux bénéficiaires. Veiller à ce que les mentors cliniques aident les établissements de santé à assurer la qualité des services cliniques et à mettre en place un système continu d’assurance qualité. Contribuer à l’élaboration du plan de Santé du District et au suivi des progrès réalisés dans les activités / performances de renforcement des compétences cliniques par rapport au plan de travail, et en respectant les exigences du rapportage. Fournir un suivi sur le terrain et documenter les progrès accomplis dans la prestation de services de haute qualité en SMNE, y compris le PEV et le paludisme au niveau de l'établissement de santé dans le district. Assister et aider l'EMAD à identifier les opportunités et à coordonner les activités de renforcement des compétences cliniques avec d'autres bailleurs de fonds internationaux\xa0sur des questions de gestion clinique ou d'autres domaines pertinents dans le district. Assurer la supervision technique des activités de renforcement des compétentes cliniques dans le district. Assurer la soumission en temps des rapports d'avancement des activités au coordinateur du renforcement des compétences cliniques et au coordinateur de district S'acquitter de toutes autres tâches assignées QUALIFICATIONS REQUISES Diplôme universitaire supérieur en prestation de services cliniques (médecin, infirmière sage-femme ou équivalent) Deux à trois ans d'expérience en assistance technique aux prestataires de services de SR / PF, SMNE, paludisme et PEV, y compris la formation / coaching / mentorat clinique, et dans le suivi des livrables et des résultats des services cliniques. Connaissance significative du système de santé de Madagascar. Expérience de travail sur des programmes financés par l'USAID est un avantage. Expérience dans l'élaboration et la prestation de formations et d'ateliers. Expérience de la formation, de l'encadrement et du mentorat; expérience de la mise en place de programmes de formation et d'ateliers est souhaité. Aptitude avérée à interagir de manière professionnelle et efficace avec les cadres supérieurs, les décideurs, les responsables gouvernementaux et la société civile. Compétences pratiques et analytiques nécessaires pour interpréter des données ou des informations en actions concrètes. Créativité, adaptabilité et capacité à appliquer une pensée innovatrice et à résoudre des problèmes. Compétences fortes en informatique et en écriture. Volonté et capacité à s'adapter aux besoins du programme en foncti ...
# printingpostings
# [{'labels': ['Spécialiste du renforcement des capacités cliniques du district - Vatomandry (Région Atsinanana)', 'R733', 'Madagascar-Atsinanana', 'Posted Today'], 'description': "MISSION PRINCIPALE Le Spécialiste du renforcement des compétences cliniques au niveau de district travaille ensemble avec l'EMAD pour identifier, planifier et mettre en œuvre le renforcement des compétences basées sur les besoins identifiés en visant à améliorer la qualité des services de SMNE dans les hôpitaux de district et les CSB. Il/elle veille à ce que le projet reste conforme aux objectifs des activités de renforcement des capacités cliniques et aux objectifs de la SMNE dans le district. RESPONSIBILITÉS SPÉCIFIQUES En collaboration avec le Coordonnateur Régional du Renforcement des Compétences Cliniques, il/elle aidera l'EMAD à développer la formation polyvalente optimale, par un appui formatif et de mentorat sur site et hors site pour chaque lacune de performance clinique identifiée. Assister l'EMAD à dispenser une formation clinique initiale adaptée au curriculum actualisé pour le personnel des hôpitaux et des CSB du district. Aider l'EMAD à optimiser les prestations des mentors cliniques afin d'améliorer la prestation de services, en ciblant les CSB et les hôpitaux de district par une assistance technique adaptée. Veiller à ce que l’orientation des interventions cliniques, activités et programme soient mise en œuvre avec une haute qualité technique et à ce que les produits associés soient livrés à temps aux bénéficiaires. Veiller à ce que les mentors cliniques aident les établissements de santé à assurer la qualité des services cliniques et à mettre en place un système continu d’assurance qualité. Contribuer à l’élaboration du plan de Santé du District et au suivi des progrès réalisés dans les activités / performances de renforcement des compétences cliniques par rapport au plan de travail, et en respectant les exigences du rapportage. Fournir un suivi sur le terrain et documenter les progrès accomplis dans la prestation de services de haute qualité en SMNE, y compris le PEV et le paludisme au niveau de l'établissement de santé dans le district. Assister et aider l'EMAD à identifier les opportunités et à coordonner les activités de renforcement des compétences cliniques avec d'autres bailleurs de fonds internationaux\xa0sur des questions de gestion clinique ou d'autres domaines pertinents dans le district. Assurer la supervision technique des activités de renforcement des compétentes cliniques dans le district. Assurer la soumission en temps des rapports d'avancement des activités au coordinateur du renforcement des compétences cliniques et au coordinateur de district S'acquitter de toutes autres tâches assignées QUALIFICATIONS REQUISES Diplôme universitaire supérieur en prestation de services cliniques (médecin, infirmière sage-femme ou équivalent) Deux à trois ans d'expérience en assistance technique aux prestataires de services de SR / PF, SMNE, paludisme et PEV, y compris la formation / coaching / mentorat clinique, et dans le suivi des livrables et des résultats des services cliniques. Connaissance significative du système de santé de Madagascar. Expérience de travail sur des programmes financés par l'USAID est un avantage. Expérience dans l'élaboration et la prestation de formations et d'ateliers. Expérience de la formation, de l'encadrement et du mentorat; expérience de la mise en place de programmes de formation et d'ateliers est souhaité. Aptitude avérée à interagir de manière professionnelle et efficace avec les cadres supérieurs, les décideurs, les responsables gouvernementaux et la société civile. Compétences pratiques et analytiques nécessaires pour interpréter des données ou des informations en actions concrètes. Créativité, adaptabilité et capacité à appliquer une pensée innovatrice et à résoudre des problèmes. Compétences fortes en informatique et en écriture. Volonté et capacité à s'adapter aux besoins du programme en foncti ...

# %%
from crawler import get_job_postings
import os, json
import pandas as pd
import requests
import re

#data = get_job_postings('https://msh.wd1.myworkdayjobs.com/en-US/External',4,False)
#print(data)

immunization_keywords = ['Immunization', 'immunisation', 'vaccine', 'vaccines','vaccine-preventable diseases', 'vpd outbreak',
                        'immunization campaign', 'SIA','supplemental immunization act ivities', 'cold chain', 'GAVI','shigella', 'cholera',
                        'bcg', 'dtp', 'dpt', 'measles', 'influenza', 'conjugate vaccine']
            
economics_keywords = ['Economics','expenditure tracking', 'financing', 
                    'value for vaccination' , 'costing', 'economic analysis','costs' , 'equity', 'cost effectiveness', 'cost-effectiveness', 
                    'cost benefit analysis', 'benefit-cost analysis','cost utility analysis','budget impact analysis' , 'budget' , 'budgeting' , 
                    'GAVI','funding gap','fiscal']


new_json_files = []
#print(data)
for json_text in data:
    #print(json_text)
    desc = json_text['description']
    imm_result = any(ele in desc for ele in immunization_keywords)
    ec_result = any(ele in desc for ele in economics_keywords)
    #print(result)
    if (imm_result or ec_result):
        if json_text not in new_json_files:
            json_text['immunization'] = imm_result
            json_text['economics'] = ec_result
            new_json_files.append(json_text)  
                
#print(new_json_files)

job_position = []
description_and_requirements = []
location = []
ImmEcs = []
organization = []
pageurl = []

for index in new_json_files:
    #print(index)   
    jp = index['labels'][0]
    job_position.append(jp)
    #print(job_position)
    description = index['description']
    description_and_requirements.append(description)
    #print(description_and_requirements)
    loc = index['labels'][2]
    loc = re.sub('-',',',loc)
    location.append(loc)
    #print(location)
    if (imm_result and ec_result): ImmEcs.append('Both')
    elif imm_result: ImmEcs.append('Immunization')
    else: ImmEcs.append('Economics')
    organization.append('MSH')
    pageurl.append('https://msh.wd1.myworkdayjobs.com/en-US/External')

DataFrame = pd.DataFrame() 
DataFrame['Job']= job_position 
DataFrame['Location'] = location
DataFrame['Type'] = ImmEcs
DataFrame['Description'] = description_and_requirements 
DataFrame['Organization'] = organization

Data = DataFrame.drop_duplicates() 
Data.to_csv("MSH_Data.csv")
print('Done')
# Out:
# Done
