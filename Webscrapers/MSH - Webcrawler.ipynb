# %%
from crawler import get_job_postings
import os, json
import pandas as pd
import requests

# %%
data = get_job_postings('https://msh.wd1.myworkdayjobs.com/en-US/External',4,False)
#print(data)
# Out:
# printingpostings
# []
# printingpostings
# [{'labels': ['Gestionnaire en Administration des Ressources Humaines', 'R675', 'Madagascar-Antananarivo', 'Posted Today'], 'description': "RESPONSABILITES GLOBALES Le Gestionnaire en Administration des Ressources Humaines fournit un soutien global aux ressources humaines du programme. Il / elle est chargé de l’administration en général du personnel et est responsable de la sincérité, complétude et mises à jour des systèmes d’information des ressources humaines (systèmes physique et électronique). Il / elle soutient la création d'un environnement de travail sain par le biais de politiques ouvertes, du partage d'informations et de l'organisation des fonctions du personnel. Il / elle travaille soutient fortement la réalisation des buts et objectifs de l'organisation et des programmes par le biais du développement, de la mise en œuvre et de la gestion d'activités visant à renforcer les capacités et l'infrastructure des ressources humaines sur le terrain. RESPONSABILITÉS SPÉCIFIQUES Garantir à tout moment la disponibilité de toutes informations relatives au personnel, consultants, temporaires, etc. en tenant les dossiers y afférents, tant par un classement physique qu’électronique. Maintenir un système de suivi de gestion des absences (congé annuel, congés de maladie, permission, …). Fournir aux employés, aux directeurs et au responsable des ressources humaines des informations sur les soldes de congés des employés tous les mois et chaque fois que cela est nécessaire\xa0; et s’assurer de l’adhésion et de l’application des procédures d’absences par tout le personnel du projet. Etablir les éléments de paie mensuelle pour validation du HR Manager, coordonner le traitement avec le cabinet externe\xa0selon le calendrier établi (heures supplémentaires, nouveaux embauches, départ, absences, changements, etc.), et procéder à la vérification du calcul de la paie par le cabinet S’assurer de la disponibilité des fiches de paie auprès des employés concernés\xa0: préparer les fiches de paie pour leur signature (par le HR Manager et le Director F&A), distribuer les fiches de paie individuelles aux employés respectifs (envoi par mail aux employés des régions), et gérer le classement des fiches de paie. Préparer les contrats de travail et tous documents d’embauche, et s’assurer de leurs compréhension et diffusion effective aux concernés. Préparer aussi les diverses avenants et/notifications relatifs aux changements éventuels dans l’emploi des staff. Intervenir dans l’orientation des nouveaux employés en matière de gestion administrative RH avec les politiques et les procédures RH, et en gestion de la performance, fixation des objectifs, et de gestion de formation (avec les cours obligatoires nécessaires). Produire des rapports réguliers sur la situation de l’effectif et les sujets traités ci-dessus. Diffuser les notes de service et autres informations internes nécessaires à l’administration efficiente du personnel. Coordonner l'administration des avantages accordés au personnel. Et en collaboration avec le responsable des ressources humaines, veillez à ce que l'ensemble des avantages sociaux soit revu annuellement et fournir des recommandations au bureau des rémunérations pour les modifications. Proposer les mises en place, révision des procédures RH selon l’évolution du contexte et conformément aux pratiques légales. Comprendre et interpréter les stratégies du personnel MSH. Suggérer des modifications au manuel des employés locaux, conformément aux politiques de MSH et au code du travail local. Selon le cas, conseiller les employés sur des questions confidentielles relatives à l'emploi, le développement de carrière, la satisfaction au travail et les problèmes de griefs et de discipline. Fournir des conseils sur les procédures et les options pour la résolution des conflits. S’acquitter de toute autre tâche demandée par le superviseur et entrant dans le cadre de ses compétences. QUALIFICATIONS Diplôme ou formation équivalente pertinente et 2 à 4 an ...
# printingpostings
# [{'labels': ['Gestionnaire en Administration des Ressources Humaines', 'R675', 'Madagascar-Antananarivo', 'Posted Today'], 'description': "RESPONSABILITES GLOBALES Le Gestionnaire en Administration des Ressources Humaines fournit un soutien global aux ressources humaines du programme. Il / elle est chargé de l’administration en général du personnel et est responsable de la sincérité, complétude et mises à jour des systèmes d’information des ressources humaines (systèmes physique et électronique). Il / elle soutient la création d'un environnement de travail sain par le biais de politiques ouvertes, du partage d'informations et de l'organisation des f
s’assurer de l’adhésion et de l’application des procédures d’absences par tout le personnel du projet. Etablir les éléments de paie mensuelle pour validation du HR Manager, coordonner le traitement avec le cabinet externe\xa0selon le calendrier établi (heures supplémentaires, nouveaux embauches, départ, absences, changements, etc.), et procéder à la vérification du calcul de la paie par le cabinet S’assurer de la disponibilité des fiches de paie auprès des employés concernés\xa0: préparer les fiches de paie pour leur signature (par le HR Manager et le Director F&A), distribuer les fiches de paie individuelles aux employés respectifs (envoi par mail aux employés des régions), et gérer le classement des fiches de paie. Préparer les contrats de travail et tous documents d’embauche, et s’assurer de leurs compréhension et diffusion effective aux concernés. Préparer aussi les diverses avenants et/notifications relatifs aux changements éventuels dans l’emploi des staff. Intervenir dans l’orientation des nouveaux employés en matière de gestion administrative RH avec les politiques et les procédures RH, et en gestion de la performance, fixation des objectifs, et de gestion de formation (avec les cours obligatoires nécessaires). Produire des rapports réguliers sur la situation de l’effectif et les sujets traités ci-dessus. Diffuser les notes de service et autres informations internes nécessaires à l’administration efficiente du personnel. Coordonner l'administration des avantages accordés au personnel. Et en collaboration avec le responsable des ressources humaines, veillez à ce que l'ensemble des avantages sociaux soit revu annuellement et fournir des recommandations au bureau des rémunérations pour les modifications. Proposer les mises en place, révision des procédures RH selon l’évolution du contexte et conformément aux pratiques légales. Comprendre et interpréter les stratégies du personnel MSH. Suggérer des modifications au manuel des employés locaux, conformément aux politiques de MSH et au code du travail local. Selon le cas, conseiller les employés sur des questions confidentielles relatives à l'emploi, le développement de carrière, la satisfaction au travail et les problèmes de griefs et de discipline. Fournir des conseils sur les procédures et les options pour la résolution des conflits. S’acquitter de toute autre tâche demandée par le superviseur et entrant dans le cadre de ses compétences. QUALIFICATIONS Diplôme ou formation équivalente pertinente et 2 à 4 an ...

# %%
immunization_keywords = ['Immunization', 'immunisation', 'vaccine', 'vaccines','vaccine-preventable diseases', 'vpd outbreak',
                        'immunization campaign', 'SIA','supplemental immunization act ivities', 'cold chain', 'GAVI','shigella', 'cholera',
                        'bcg', 'dtp', 'dpt', 'measles', 'influenza', 'conjugate vaccine']
            
economics_keywords = ['Economics','expenditure tracking', 'financing', 
                    'value for vaccination' , 'costing', 'economic analysis','costs' , 'equity', 'cost effectiveness', 'cost-effectiveness', 
                    'cost benefit analysis', 'benefit-cost analysis','cost utility analysis','budget impact analysis' , 'budget' , 'budgeting' , 
                    'GAVI','funding gap','fiscal']


new_json_files = []
#print(data)
for json_text in data:
    #print(json_text)
    desc = json_text['description']
    immun = any(ele in desc for ele in immunization_keywords)
    econ = any(ele in desc for ele in economics_keywords)
    #print(result)
    if (immun or econ):
        if json_text not in new_json_files:
            json_text['immunization'] = immun
            json_text['economics'] = econ
            new_json_files.append(json_text)  
                
#print(new_json_files)

job_position = []
description_and_requirements = []
location = []
immunization = []
economics = []
organization = []

for index in new_json_files:
    #print(index)   
    jp = index['labels'][0]
    job_position.append(jp)
    #print(job_position)
    description = index['description']
    description_and_requirements.append(description)
    #print(description_and_requirements)
    loc = index['labels'][2]
    location.append(loc)
    #print(location)
    immunization.append(index['immunization'])
    economics.append(index['economics'])
    organization.append('MSH')

DataFrame = pd.DataFrame() 
DataFrame['Job']= job_position 
DataFrame['Description and Requirements'] = description_and_requirements 
DataFrame['Location'] = location
DataFrame['Immunization'] = immunization
DataFrame['Economics'] = economics
DataFrame['Organization'] = organization

Data = DataFrame.drop_duplicates() 
Data.to_csv("MSH_Data.csv")
print('Done')
# Out:
# Done
