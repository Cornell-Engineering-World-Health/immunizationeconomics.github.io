# %%
import requests
from bs4 import BeautifulSoup as bs
import re
import csv
 
import pandas as pd

url = 'https://www.rockefellerfoundation.org/grants/'

#requesting a session in the specific url
with requests.Session() as s:
    r = s.get(url)
    src = r.content
    soup = bs(src)
    soup.prettify()
    descriptions = []
    allPages = []
    amounts = []
    names = []
    while url != '':  
        print(url)
        r = s.get(url)
        src = r.content
        soup = bs(src)
        soup.prettify()
        next_link = str(soup.find_all('li', {'class': 'next btn'}))
        next_link = next_link[60:]
        next_link = next_link[:next_link.find('>')]
        data = soup.find_all('div', {'class': 'grant-left'})
        for link in data:
                url = link.find('a').get('href')
                allPages.append(url)
                page_source = s.get(url).content
                soup = bs(page_source) 
                soup.prettify()
                soup = str(soup)
                description_index1 = soup.find("<h2>Description:</h2> <span>")
                description_index2 = soup[description_index1:].find("</sp")
                descriptions.append(soup[description_index1+28:description_index1 + description_index2])
                name_index1 = soup.find("<title>")
                name_index2 = soup[name_index1:].find("-") - 1
                names.append(soup[name_index1+7:name_index1 + name_index2])
                amount_index1 = soup.find("<span>$")
                amount_index2 = soup[amount_index1:].find("</span>")
                amounts.append(soup[amount_index1 + 6:amount_index1  + amount_index2])
        url = next_link 
    
    
DataFrame = pd.DataFrame()
DataFrame['Page URL'] = allPages
DataFrame['Name'] = names
DataFrame['Description'] = descriptions
DataFrame['Amount'] = amounts
    
Data = DataFrame.drop_duplicates() 
Data.to_csv("Rockefeller_Funding_Data.csv")

print('Webscraping complete')
# Out:
# https://www.rockefellerfoundation.org/grants/
# https://www.rockefellerfoundation.org/grants/page/2/"
# https://www.rockefellerfoundation.org/grants/page/3/"
# https://www.rockefellerfoundation.org/grants/page/4/"
# https://www.rockefellerfoundation.org/grants/page/5/"
# https://www.rockefellerfoundation.org/grants/page/6/"
# https://www.rockefellerfoundation.org/grants/page/7/"
# https://www.rockefellerfoundation.org/grants/page/8/"
# https://www.rockefellerfoundation.org/grants/page/9/"
# https://www.rockefellerfoundation.org/grants/page/10/"
# https://www.rockefellerfoundation.org/grants/page/11/"
# https://www.rockefellerfoundation.org/grants/page/12/"
# https://www.rockefellerfoundation.org/grants/page/13/"
# https://www.rockefellerfoundation.org/grants/page/14/"
# https://www.rockefellerfoundation.org/grants/page/15/"
# https://www.rockefellerfoundation.org/grants/page/16/"
# https://www.rockefellerfoundation.org/grants/page/17/"
# https://www.rockefellerfoundation.org/grants/page/18/"
# https://www.rockefellerfoundation.org/grants/page/19/"
# https://www.rockefellerfoundation.org/grants/page/20/"
# https://www.rockefellerfoundation.org/grants/page/21/"
# https://www.rockefellerfoundation.org/grants/page/22/"
# https://www.rockefellerfoundation.org/grants/page/23/"
# https://www.rockefellerfoundation.org/grants/page/24/"
# https://www.rockefellerfoundation.org/grants/page/25/"
# https://www.rockefellerfoundation.org/grants/page/26/"
# https://www.rockefellerfoundation.org/grants/page/27/"
# https://www.rockefellerfoundation.org/grants/page/28/"
# https://www.rockefellerfoundation.org/grants/page/29/"
# https://www.rockefellerfoundation.org/grants/page/30/"
# https://www.rockefellerfoundation.org/grants/page/31/"
# https://www.rockefellerfoundation.org/grants/page/32/"
# https://www.rockefellerfoundation.org/grants/page/33/"
# https://www.rockefellerfoundation.org/grants/page/34/"
# https://www.rockefellerfoundation.org/grants/page/35/"
# https://www.rockefellerfoundation.org/grants/page/36/"
# https://www.rockefellerfoundation.org/grants/page/37/"
# https://www.rockefellerfoundation.org/grants/page/38/"
# https://www.rockefellerfoundation.org/grants/page/39/"
# https://www.rockefellerfoundation.org/grants/page/40/"
# https://www.rockefellerfoundation.org/grants/page/41/"
# https://www.rockefellerfoundation.org/grants/page/42/"
# https://www.rockefellerfoundation.org/grants/page/43/"
